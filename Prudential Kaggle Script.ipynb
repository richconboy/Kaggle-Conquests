# %% [markdown]
# ##Prudential Life Insurance Assessment
# *Code by Rich Conboy*

# %%
import pandas as pd
import seaborn as sns

# %%
#Read in Data
training_data = pd.read_csv('C:/Users/Rich\OneDrive/Documents/Independent Projects/Kaggle Data and Submissions/Prudential/train.csv', index_col = 'Id')
test_data = pd.read_csv('C:/Users/Rich/OneDrive/Documents/Independent Projects/Kaggle Data and Submissions/Prudential/test.csv', index_col = 'Id')

# %%
#Summary Statistics - Note: This only shows a fraction of the 126 columns
training_data.describe()
# Out:
#        Product_Info_1  Product_Info_3  Product_Info_4  Product_Info_5  \
# count    59381.000000    59381.000000    59381.000000    59381.000000
# mean         1.026355       24.415655        0.328952        2.006955
# std          0.160191        5.072885        0.282562        0.083107
# min          1.000000        1.000000        0.000000        2.000000
# 25%          1.000000       26.000000        0.076923        2.000000
# 50%          1.000000       26.000000        0.230769        2.000000
# 75%          1.000000       26.000000        0.487179        2.000000
# max          2.000000       38.000000        1.000000        3.000000
#
#        Product_Info_6  Product_Info_7       Ins_Age            Ht  \
# count    59381.000000    59381.000000  59381.000000  59381.000000
# mean         2.673599        1.043583      0.405567      0.707283
# std          0.739103        0.291949      0.197190      0.074239
# min          1.000000        1.000000      0.000000      0.000000
# ...

# %%
#Bar Chart Columns with Missing Values - There must be an easier/more efficient way to do this
colnames = []
nmissing = []

for col in training_data.columns:
    if training_data[col].count() < len(training_data):
        colnames.append(col)
        nmissing.append(len(training_data) - training_data[col].count())
        
missing_count = pd.DataFrame({'Name': colnames,
                             'Num Missing': nmissing})
 
a = sns.barplot(x='Name', y='Num Missing', data=missing_count, palette='husl')
for item in a.get_xticklabels():
    item.set_rotation(45)

# %%
#Look at Distribution of Response Variable
# %matplotlib inline
sns.countplot(x='Response', data=training_data, palette="husl", order = range(1,9))

# %%
Split Training Data Into Training and Validation
X_train, X_validation, y_train, y_validation = cross_validation.train_test_split(X, y, test_size = 0.25, random_state = 5)
